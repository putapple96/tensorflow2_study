# %% [markdown]
# ## XOR Problem using neural networks

# %% [markdown]
# 싱글 노드로 해결이 불가능 하므로 두 개의 노드로 XOR 문제를 해결

# %%
import tensorflow as tf
import numpy as np

x_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype=np.float32)
y_data = np.array([[0], [1], [1], [0]], dtype=np.float32)

# %%
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=2, input_dim=2))
tf.model.add(tf.keras.layers.Activation('sigmoid'))
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2))
tf.model.add(tf.keras.layers.Activation('sigmoid'))

tf.model.compile(loss='binary_crossentropy', optimizer=tf.optimizers.SGD(lr=0.1),
                 metrics=['accuracy'])
tf.model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 2)                 6
# _________________________________________________________________
# activation (Activation)      (None, 2)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 3
# _________________________________________________________________
# activation_1 (Activation)    (None, 1)                 0
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_history = tf.model.fit(x_data, y_data, epochs=5000)
# Out:
# Train on 4 samples
# Epoch 1/5000
# 4/4 [==============================] - 1s 310ms/sample - loss: 0.7285 - accuracy: 0.5000
# Epoch 2/5000
# 4/4 [==============================] - 0s 997us/sample - loss: 0.7259 - accuracy: 0.5000
# Epoch 3/5000
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7235 - accuracy: 0.5000
# Epoch 4/5000
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7212 - accuracy: 0.5000
# Epoch 5/5000
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.7191 - accuracy: 0.5000
# Epoch 6/5000
# 4/4 [==============================] - 0s 990us/sample - loss: 0.7172 - accuracy: 0.5000
# Epoch 7/5000
# 4/4 [==============================] - 0s 989us/sample - loss: 0.7154 - accuracy: 0.5000
# Epoch 8/5000
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7137 - accuracy: 0.5000
# Epoch 9/5000
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.7121 - accuracy: 0.5000
# Epoch 10/5000
# ...

# %%
pred = tf.model.predict(x_data)
print('Prediction: \n', pred)

score = tf.model.evaluate(x_data, y_data)
print("Accuracy: ", score[1])
# Out:
# Prediction:
#  [[0.04176932]
#  [0.9675652 ]
#  [0.9682151 ]
#  [0.03535675]]
# 4/4 [==============================] - 0s 84ms/sample - loss: 0.0360 - accuracy: 1.0000
# Accuracy:  1.0
